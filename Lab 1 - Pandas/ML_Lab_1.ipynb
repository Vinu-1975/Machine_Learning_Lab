# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinu-1975/Machine_Learning_Lab/blob/master/ML_Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

import seaborn as sns
# import matplotlib.pylot as plt

# %%
data =[['apple',10,240],['orange',20,150],['grapes',14,80],['pineapple',10,70]]

df1 = pd.DataFrame(data,columns = ['Fruit_name','Quantity','Unit_price'])

# %%
df1
# Out:
#   Fruit_name  Quantity  Unit_price
# 0      apple        10       240.0
# 1     orange       150         NaN
# 2     grapes        14        80.0
# 3  pineapple        10        70.0

# %%
df1.shape
# Out:
# (4, 3)

# %%
df1.info()
# to find no. of null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Fruit_name  4 non-null      object
#  1   Quantity    4 non-null      int64
#  2   Unit_price  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df1.describe()
# file member summary
# Out:
#         Quantity  Unit_price
# count   4.000000    4.000000
# mean   13.500000  135.000000
# std     4.725816   78.528127
# min    10.000000   70.000000
# 25%    10.000000   77.500000
# 50%    12.000000  115.000000
# 75%    15.500000  172.500000
# max    20.000000  240.000000

# %%
iris = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
names = ['sepal_length','sepal_width','petal_length','petal_width','class']
df = pd.read_csv(iris,sep=',',names = names)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.tail(15)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica
# 137           6.4          3.1           5.5          1.8  Iris-virginica
# 138           6.0          3.0           4.8          1.8  Iris-virginica
# 139           6.9          3.1           5.4          2.1  Iris-virginica
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.sample(6)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 13            4.3          3.0           1.1          0.1      Iris-setosa
# 43            5.0          3.5           1.6          0.6      Iris-setosa
# 107           7.3          2.9           6.3          1.8   Iris-virginica
# 130           7.4          2.8           6.1          1.9   Iris-virginica
# 100           6.3          3.3           6.0          2.5   Iris-virginica

# %%
df.dtypes
# to get datatypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# class            object
# dtype: object

# %%
df['petal_width'].dtype
# Out:
# dtype('float64')

# %%
df['petal_width']
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal_width, Length: 150, dtype: float64

# %%
df['class'].value_counts()
# diff types of class categories along with their count
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
df['class'].unique()
# only avaliable for non - numerical colums
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['class'].nunique()
# no. of unique colums
# Out:
# 3

# %%
df.isnull().sum()
# return count of null values of each attr
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %%
df.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  class
# 0           False        False         False        False  False
# 1           False        False         False        False  False
# 2           False        False         False        False  False
# 3           False        False         False        False  False
# 4           False        False         False        False  False
# ..            ...          ...           ...          ...    ...
# 145         False        False         False        False  False
# 146         False        False         False        False  False
# 147         False        False         False        False  False
# 148         False        False         False        False  False
# 149         False        False         False        False  False
#
# [150 rows x 5 columns]

# %%
df.duplicated().sum()
# no of duplicated instances
# Out:
# 3

# %%
df[df.duplicated()]
# shows the duplicated instances
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 142           5.8          2.7           5.1          1.9  Iris-virginica

# %%
df[2:10]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df.loc[5]
# Out:
# sepal_length            5.4
# sepal_width             3.9
# petal_length            1.7
# petal_width             0.4
# class           Iris-setosa
# Name: 5, dtype: object

# %%
df.iloc[5]
# return values at index 5
# Out:
# sepal_length            5.4
# sepal_width             3.9
# petal_length            1.7
# petal_width             0.4
# class           Iris-setosa
# Name: 5, dtype: object

# %%
df['petal_length']
# series
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal_length, Length: 150, dtype: float64

# %%
df.iloc[5:10]['petal_length']
# Out:
# 5    1.7
# 6    1.4
# 7    1.5
# 8    1.4
# 9    1.5
# Name: petal_length, dtype: float64

# %%
df.loc[[55,60],['sepal_width','petal_length']]
# Out:
#     sepal_width  petal_length
# 55          2.8           4.5
# 60          2.0           3.5

# %%
df.corr()
# correlation between colums in a df
# Out:
# <ipython-input-51-9935a5fccc30>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
df['sepal_length'].min()
# Out:
# 4.3

# %%
df['sepal_length'].max()
# Out:
# 7.9

# %%
import matplotlib.pyplot as plt
df.plot()
plt.show()

# %%
df.plot(kind='scatter',x='sepal_length',y='sepal_width')
plt.show()

# %%
df['sepal_length'].plot(kind='hist')
plt.show()
